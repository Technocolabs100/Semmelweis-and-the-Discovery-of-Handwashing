# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath='/cardioActivities.csv'
df_activities= pd.read_csv(filepath)
df_activities_copy = df_activities.copy()

# %%
df_activities_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      508 non-null    object
#  1   Activity Id               508 non-null    object
#  2   Type                      508 non-null    object
#  3   Route Name                1 non-null      object
#  4   Distance (km)             508 non-null    float64
#  5   Duration                  508 non-null    object
#  6   Average Pace              508 non-null    object
#  7   Average Speed (km/h)      508 non-null    float64
#  8   Calories Burned           508 non-null    float64
#  9   Climb (m)                 508 non-null    int64
#  10  Average Heart Rate (bpm)  294 non-null    float64
#  11  Friend's Tagged           0 non-null      float64
#  12  Notes                     231 non-null    object
# ...

# %%
df_activities
# Out:
#                     Date                           Activity Id     Type  \
# 0    2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 1    2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2    2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 3    2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 4    2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ..                   ...                                   ...      ...
# 503  2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 504  2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 505  2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 506  2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 507  2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#     Route Name  Distance (km) Duration Average Pace  Average Speed (km/h)  \
# ...

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      508 non-null    object
#  1   Activity Id               508 non-null    object
#  2   Type                      508 non-null    object
#  3   Route Name                1 non-null      object
#  4   Distance (km)             508 non-null    float64
#  5   Duration                  508 non-null    object
#  6   Average Pace              508 non-null    object
#  7   Average Speed (km/h)      508 non-null    float64
#  8   Calories Burned           508 non-null    float64
#  9   Climb (m)                 508 non-null    int64
#  10  Average Heart Rate (bpm)  294 non-null    float64
#  11  Friend's Tagged           0 non-null      float64
#  12  Notes                     231 non-null    object
# ...

# %%
#df_activities.reset_index(inplace=True)

# %%
df_activities['Date'] = pd.to_datetime(df_activities['Date'])
df_activities.set_index('Date', inplace=True)

# %%
random_rows = df_activities.sample(n=3)
print(random_rows)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2014-11-25 17:50:00  d6574cc9-2e03-4d1c-a0f8-e3fe8090e8c5  Running        NaN
# 2014-10-27 18:30:00  1e0bd31f-8aa0-4c22-9192-2bf32089855e  Running        NaN
# 2017-01-30 18:43:33  dcf483e9-421e-42b6-b116-884c794f5366  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2014-11-25 17:50:00           9.78    51:45         5:18
# 2014-10-27 18:30:00          12.98  1:05:45         5:04
# 2017-01-30 18:43:33           6.98    37:28         5:22
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2014-11-25 17:50:00                 11.34            655.0         51
# 2014-10-27 18:30:00                 11.85            888.0         67
# 2017-01-30 18:43:33                 11.18            497.0         66
#
#                      Average Heart Rate (bpm)  Friend's Tagged  \
# Date
# ...

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               508 non-null    object
#  1   Type                      508 non-null    object
#  2   Route Name                1 non-null      object
#  3   Distance (km)             508 non-null    float64
#  4   Duration                  508 non-null    object
#  5   Average Pace              508 non-null    object
#  6   Average Speed (km/h)      508 non-null    float64
#  7   Calories Burned           508 non-null    float64
#  8   Climb (m)                 508 non-null    int64
#  9   Average Heart Rate (bpm)  294 non-null    float64
#  10  Friend's Tagged           0 non-null      float64
#  11  Notes                     231 non-null    object
#  12  GPX File                  504 non-null    object
# ...

# %%
#Define list of columns to be deleted
col_deleted = ['Route Name','Friend\'s Tagged','Notes','GPX File'] 

#Delete unnecessary columns
df_activities.drop(col_deleted,axis=1,inplace=True)
df_activities.columns
# Out:
# Index(['Activity Id', 'Type', 'Distance (km)', 'Duration', 'Average Pace',
#        'Average Speed (km/h)', 'Calories Burned', 'Climb (m)',
#        'Average Heart Rate (bpm)'],
#       dtype='object')

# %%
df_activities['Type'].value_counts()
# Out:
# Running    459
# Cycling     29
# Walking     18
# Other        2
# Name: Type, dtype: int64

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 508 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               508 non-null    object
#  1   Type                      508 non-null    object
#  2   Distance (km)             508 non-null    float64
#  3   Duration                  508 non-null    object
#  4   Average Pace              508 non-null    object
#  5   Average Speed (km/h)      508 non-null    float64
#  6   Calories Burned           508 non-null    float64
#  7   Climb (m)                 508 non-null    int64
#  8   Average Heart Rate (bpm)  294 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 39.7+ KB

# %%
df_activities['Type'] = df_activities['Type'].str.replace('Other', 'Unicycling')

# %%
df_activities['Type'].value_counts()
# Out:
# Running       459
# Cycling        29
# Walking        18
# Unicycling      2
# Name: Type, dtype: int64

# %%
df_activities.isnull().sum()
# Out:
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# dtype: int64

# %%
df_activities['Average Heart Rate (bpm)']
# Out:
# Date
# 2018-11-11 14:05:12    159.0
# 2018-11-09 15:02:35    159.0
# 2018-11-04 16:05:00    155.0
# 2018-11-01 14:03:58    158.0
# 2018-10-27 17:01:36    154.0
#                        ...
# 2012-08-28 07:06:57      NaN
# 2012-08-24 12:59:42      NaN
# 2012-08-24 10:12:16      NaN
# 2012-08-24 08:13:12      NaN
# 2012-08-22 18:53:54      NaN
# Name: Average Heart Rate (bpm), Length: 508, dtype: float64

# %%
#gives all averages valid wher type is cycling
#avg_hr_cycle = df_activities[df_activities['Type'] == 'Cycling'].mean()
#print(avg_hr_cycle)

# %%
df_cycle = df_activities[df_activities['Type'] == 'Cycling']
avg_hr_cycle = df_cycle['Average Heart Rate (bpm)'].mean()
print("Average Heart Rate for Cycling: ", avg_hr_cycle)
# Out:
# Average Heart Rate for Cycling:  124.4

# %%
df_cycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2018-10-06 16:45:02 to 2013-04-28 17:26:52
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               29 non-null     object
#  1   Type                      29 non-null     object
#  2   Distance (km)             29 non-null     float64
#  3   Duration                  29 non-null     object
#  4   Average Pace              29 non-null     object
#  5   Average Speed (km/h)      29 non-null     float64
#  6   Calories Burned           29 non-null     float64
#  7   Climb (m)                 29 non-null     int64
#  8   Average Heart Rate (bpm)  15 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 2.3+ KB

# %%
df_cycle['Average Heart Rate (bpm)']=df_cycle['Average Heart Rate (bpm)'].fillna(avg_hr_cycle)
# Out:
# <ipython-input-23-222268f1dd21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cycle['Average Heart Rate (bpm)']=df_cycle['Average Heart Rate (bpm)'].fillna(avg_hr_cycle)

# %%
df_cycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2018-10-06 16:45:02 to 2013-04-28 17:26:52
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               29 non-null     object
#  1   Type                      29 non-null     object
#  2   Distance (km)             29 non-null     float64
#  3   Duration                  29 non-null     object
#  4   Average Pace              29 non-null     object
#  5   Average Speed (km/h)      29 non-null     float64
#  6   Calories Burned           29 non-null     float64
#  7   Climb (m)                 29 non-null     int64
#  8   Average Heart Rate (bpm)  29 non-null     float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 2.3+ KB

# %%
df_run = df_activities[df_activities['Type'] == 'Running']
#df_run
df_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 459 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               459 non-null    object
#  1   Type                      459 non-null    object
#  2   Distance (km)             459 non-null    float64
#  3   Duration                  459 non-null    object
#  4   Average Pace              459 non-null    object
#  5   Average Speed (km/h)      459 non-null    float64
#  6   Calories Burned           459 non-null    float64
#  7   Climb (m)                 459 non-null    int64
#  8   Average Heart Rate (bpm)  277 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 35.9+ KB

# %% [markdown]
# # **MISSINING VALUES ARE OMLY IN RUNNING ARE 182 IN AVG HEART RATE**

# %%
df_run.isnull().sum()
# Out:
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    182
# dtype: int64

# %%
runs_subset_2013_2018 = df_run.loc['2013':'2018']
runs_subset_2013_2018
# Out:
# <ipython-input-27-02f68e653a4c>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   runs_subset_2013_2018 = df_run.loc['2013':'2018']
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2013-01-23 18:38:29  0ee9afe5-668e-4801-9fd3-6208ec87f2e6  Running
# 2013-01-19 09:58:50  98321fac-a333-47d7-b568-1c609096a08f  Running
# 2013-01-15 18:40:08  7c512661-6a01-4ef0-80dd-b8119d5f8a59  Running
# ...

# %%
import matplotlib.pyplot as plt
runs_subset_2013_2018.plot(subplots=True,
                           sharex=False,
                           figsize=(12, 20),
                           linestyle='none',
                           marker='o',
                           markersize=5)
plt.show()

# %%
import matplotlib.pyplot as plt
runs_subset_2013_2018.plot(subplots=True,
                           sharex=False,
                           figsize=(12, 20),
                           marker='o',
                           markersize=5)
plt.show()

# %%
runs_subset_2015_2018=runs_subset_2013_2018 = df_run.loc['2015':'2018']
runs_subset_2015_2018.head()
# Out:
# <ipython-input-30-e624bf555b7c>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   runs_subset_2015_2018=runs_subset_2013_2018 = df_run.loc['2015':'2018']
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# ...

# %%
runs_subset_2015_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 303 entries, 2018-11-11 14:05:12 to 2015-01-03 17:20:00
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               303 non-null    object
#  1   Type                      303 non-null    object
#  2   Distance (km)             303 non-null    float64
#  3   Duration                  303 non-null    object
#  4   Average Pace              303 non-null    object
#  5   Average Speed (km/h)      303 non-null    float64
#  6   Calories Burned           303 non-null    float64
#  7   Climb (m)                 303 non-null    int64
#  8   Average Heart Rate (bpm)  277 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 23.7+ KB

# %%
avg_hr_run= runs_subset_2015_2018['Average Heart Rate (bpm)'].mean()
runs_subset_2015_2018['Average Heart Rate (bpm)']= runs_subset_2015_2018['Average Heart Rate (bpm)'].fillna(avg_hr_run)

# %%
df_resampled_runs_subset_2015_2018 = runs_subset_2015_2018.resample('A').mean()
print(df_resampled_runs_subset_2015_2018)
# Out:
#             Distance (km)  Average Speed (km/h)  Calories Burned   Climb (m)  \
# Date
# 2015-12-31      13.602805             10.998902       932.906138  160.170732
# 2016-12-31      11.411667             10.837778       796.152777  133.194444
# 2017-12-31      12.935176             10.959059       914.164706  169.376471
# 2018-12-31      13.339063             10.777969       952.359375  191.218750
#
#             Average Heart Rate (bpm)
# Date
# 2015-12-31                143.509906
# 2016-12-31                143.512084
# 2017-12-31                145.270248
# 2018-12-31                148.155799
# <ipython-input-33-00f144e9253a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_resampled_runs_subset_2015_2018 = runs_subset_2015_2018.resample('A').mean()

# %%
df_resampled_runs_subset_2015_2018_1 = runs_subset_2015_2018.resample('W').mean()
print(df_resampled_runs_subset_2015_2018_1)
# Out:
#             Distance (km)  Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2015-01-04       9.780000             11.120000       654.000000       51.0
# 2015-01-11            NaN                   NaN              NaN        NaN
# 2015-01-18       9.780000             11.230000       654.500000       51.0
# 2015-01-25            NaN                   NaN              NaN        NaN
# 2015-02-01       9.893333             10.423333       707.624448       58.0
# ...                   ...                   ...              ...        ...
# 2018-10-14      12.620000             10.840000       928.000000      146.5
# 2018-10-21      10.290000             10.410000       764.000000      133.0
# 2018-10-28      13.020000             10.730000       967.000000      170.0
# 2018-11-04      12.995000             10.420000       963.500000      170.0
# 2018-11-11      11.640000             10.535000       864.000000      149.0
#
#             Average Heart Rate (bpm)
# Date
# ...

# %%
runs_subset_2015_2018.resample('W').mean().mean()
# Out:
# <ipython-input-35-98ede2350234>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   runs_subset_2015_2018.resample('W').mean().mean()
# Distance (km)                12.518176
# Average Speed (km/h)         10.835473
# Calories Burned             877.861969
# Climb (m)                   158.325444
# Average Heart Rate (bpm)    144.883419
# dtype: float64

# %%
weekly_counts_average=runs_subset_2015_2018['Distance (km)'].resample('W').count().mean()
weekly_counts_average
# Out:
# 1.5

# %%
runs_distance=runs_subset_2015_2018['Distance (km)']
runs_hr=runs_subset_2015_2018['Average Heart Rate (bpm)']

# %%
fig, (ax1, ax2)=plt.subplots(2, 1, sharex=True, figsize=(12, 8))
ax1.plot(runs_distance.index, runs_distance)
ax1.set_ylabel('Distance (km)')
average_hr = runs_hr.mean()
ax2.plot(runs_distance)
ax2.axhline(average_hr, color='blue', linewidth=1, linestyle='-.')
ax2.set_ylabel('Average Heart Rate (bpm)')
plt.show()

# %% [markdown]
# # New Section

# %%
df_run=df_run.loc['2013':'2018']
df_run
# Out:
# <ipython-input-41-5b3e4d5877be>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_run=df_run.loc['2013':'2018']
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2013-01-23 18:38:29  0ee9afe5-668e-4801-9fd3-6208ec87f2e6  Running
# 2013-01-19 09:58:50  98321fac-a333-47d7-b568-1c609096a08f  Running
# 2013-01-15 18:40:08  7c512661-6a01-4ef0-80dd-b8119d5f8a59  Running
# ...

# %%
df_run_dist=df_run['Distance (km)']
df_run_dist
# Out:
# Date
# 2018-11-11 14:05:12    10.44
# 2018-11-09 15:02:35    12.84
# 2018-11-04 16:05:00    13.01
# 2018-11-01 14:03:58    12.98
# 2018-10-27 17:01:36    13.02
#                        ...
# 2013-01-23 18:38:29     8.65
# 2013-01-19 09:58:50     3.39
# 2013-01-15 18:40:08     6.72
# 2013-01-12 08:39:55     3.09
# 2013-01-02 18:35:11     5.47
# Name: Distance (km), Length: 438, dtype: float64

# %%
df_run_dist_annual=df_run_dist.resample('Y').sum()
print(df_run_dist_annual)
# Out:
# Date
# 2013-12-31     498.25
# 2014-12-31     755.76
# 2015-12-31    1115.43
# 2016-12-31     821.64
# 2017-12-31    1099.49
# 2018-12-31     853.70
# Freq: A-DEC, Name: Distance (km), dtype: float64

# %% [markdown]
# # IN 2015 AND 2017 I ACHIEVED MY GOAL

# %%
fig = plt.figure(figsize=(8, 5))
ax = df_run_dist_annual.plot(marker='*', markersize=10, linewidth=0, color='blue')
ax.set(ylim=[0, 2000], 
       xlim=['2013','2018'],
       ylabel='Distance (km)',
       xlabel='Years',
       title='Annual totals for distance')
ax.axhspan(0, 2000, color='red', alpha=0.2)
plt.show()

# %%
import statsmodels.api as sm
df_run_dist.info()
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 438 entries, 2018-11-11 14:05:12 to 2013-01-02 18:35:11
# Series name: Distance (km)
# Non-Null Count  Dtype
# --------------  -----
# 438 non-null    float64
# dtypes: float64(1)
# memory usage: 6.8 KB

# %%
df_run_dist.isnull().sum()
# Out:
# 0

# %%
df_run_dist_wkly=df_run_dist.resample('W').bfill()
decomposed = sm.tsa.seasonal_decompose(df_run_dist_wkly, extrapolate_trend=1, period=52)

# %%
fig = plt.figure(figsize=(12, 5))
# Plot and customize
ax = decomposed.trend.plot(label='Trend', linewidth=2)
ax = decomposed.observed.plot(label='Observed', linewidth=0.5)

ax.legend()
ax.set_title('Running distance trend')

# Show plot
plt.show()

# %%
df_run=df_run.loc['2015':'2018']
df_run_hr_all=df_run['Average Heart Rate (bpm)']
# Out:
# <ipython-input-49-d45825bceee9>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df_run=df_run.loc['2015':'2018']

# %%
fig, ax = plt.subplots(figsize=(8, 5))
# Customize x-axis tick labels
zone_names = ['Zone A', 'Zone B', 'Zone C', 'Zone D', 'Zone E']
ax.set_xticklabels(zone_names, rotation=-30, ha='left')


################
ax.hist(df_run_hr_all, bins=10, color='skyblue', edgecolor='green')

# Add labels and title
ax.set_xlabel('Heart Rate (bpm)')
ax.set_ylabel('Frequency')
ax.set_title('Heart Rate Distribution')

# Show the plot
plt.show()
# Out:
# <ipython-input-52-80c6acc9b701>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(zone_names, rotation=-30, ha='left')
